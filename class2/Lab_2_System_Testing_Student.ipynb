# %% [markdown]
# # Lab 2: AI System Testing Framework (Student Version)
#
# ## Overview
# In this lab, you will build a complete **AI system testing framework** that integrates everything from Class 2.
#
# ### What You'll Build:
# 1. **CNN API** using FastAPI (based on Part 1)
# 2. **API Test Suite** with various test cases
# 3. **Drift Detection System** to monitor performance
# 4. **Model Comparison Report** analyzing results
#
# ### Learning Objectives:
# - Implement production-ready ML APIs
# - Write comprehensive test suites for AI systems
# - Detect data drift and quality degradation
# - Generate insights from system performance metrics
#
# ### Time Allocation:
# - **Section 1**: API Implementation (30 min)
# - **Section 2**: API Testing (30 min)
# - **Section 3**: Drift Detection (20 min)
# - **Section 4**: Analysis & Report (20 min)
#
# ---
#
# ## Submission Checklist
# Before submitting, ensure you have completed:
#
# - [ ] Section 1: API endpoints implemented and working
# - [ ] Section 2: At least 8 test cases passing
# - [ ] Section 3: Drift detector detecting 2+ drift scenarios
# - [ ] Section 4: Report generated with visualizations
# - [ ] All TODO items completed
# - [ ] Code runs without errors
# - [ ] Answers to all 5 analysis questions
# - [ ] Summary statistics displayed in final section
#
# ---

# %% [markdown]
# ## Section 1: API Implementation
#
# ### Task: Implement the CNN API endpoints
# Reference: Part 1 of Class 2 covers FastAPI implementation in detail.

# %%
import os
import io
import json
import time
import numpy as np
import pandas as pd
from pathlib import Path
from PIL import Image, ImageEnhance
from datetime import datetime
from collections import defaultdict

import torch
import torch.nn as nn
import torchvision.transforms as transforms
from torchvision.models import resnet18

from fastapi import FastAPI, File, UploadFile, HTTPException
from fastapi.testclient import TestClient
from pydantic import BaseModel

import matplotlib.pyplot as plt
import seaborn as sns

print("✅ Libraries imported")

# %%
# Setup configuration
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
CLASS_NAMES = ['animal', 'name_board', 'other_vehicle', 'pedestrian', 'pothole', 'road_sign', 'speed_breaker']
NUM_CLASSES = len(CLASS_NAMES)
MODEL_VERSION = "1.0.0"

print(f"✅ Device: {DEVICE}")
print(f"✅ Classes: {CLASS_NAMES}")

# %%
# TODO: Create the CNN Model class
# Hints:
# - Use ResNet-18 as base architecture
# - Modify the final fully connected layer for NUM_CLASSES
# - Make it a nn.Module subclass
# - Implement forward() method

class CNNModel(nn.Module):
    """TODO: Implement CNN model architecture"""
    def __init__(self, num_classes):
        super().__init__()
        # TODO: Initialize ResNet-18
        # TODO: Modify final layer for num_classes
        pass
    
    def forward(self, x):
        # TODO: Implement forward pass
        pass

print("TODO: CNN Model class needs implementation")

# %%
# Create and initialize model
# TODO: Instantiate CNNModel with NUM_CLASSES
# TODO: Move model to DEVICE
# TODO: Set to eval mode

model = None  # TODO: Replace with actual model instantiation

if model is not None:
    print(f"✅ Model created and moved to {DEVICE}")
else:
    print("⚠️  Model not yet initialized")

# %%
# TODO: Define image transformation pipeline
# Hints:
# - Resize to 128x128
# - Convert to tensor
# - Normalize with ImageNet stats

transform = None  # TODO: Create transforms.Compose with appropriate transformations

if transform is not None:
    print("✅ Image transformation pipeline created")
else:
    print("⚠️  Transform not yet defined")

# %%
# TODO: Define Pydantic response models
# Hints:
# - Create PredictionResponse with fields: prediction, confidence, model_version, latency_ms
# - Create ComparisonResponse with v1/v2 predictions and agreement status

class PredictionResponse(BaseModel):
    """TODO: Define response schema for predictions"""
    pass

class ComparisonResponse(BaseModel):
    """TODO: Define response schema for multi-model comparisons"""
    pass

print("TODO: Response models need definition")

# %%
# TODO: Create FastAPI application
# Hints:
# - Use FastAPI(title=..., description=..., version=...)
# - Create a global list to store prediction logs

app = None  # TODO: Create FastAPI instance
prediction_logs = []  # TODO: Initialize log storage

if app is not None:
    print("✅ FastAPI application created")
else:
    print("⚠️  FastAPI app not yet initialized")

# %%
# TODO: Implement /predict endpoint
# Hints:
# - Accept file upload with @app.post("/predict")
# - Validate file type (only image formats)
# - Load and transform image
# - Run model inference
# - Return PredictionResponse with prediction, confidence, version, latency
# - Handle errors gracefully

if app is not None:
    # TODO: Add endpoint implementation
    pass

print("TODO: /predict endpoint needs implementation")

# %%
# TODO: Implement /health endpoint
# Hints:
# - Return status, model_version, classes, device

if app is not None:
    # TODO: Add health check endpoint
    pass

print("TODO: /health endpoint needs implementation")

# %%
# TODO: Implement /info endpoint
# Hints:
# - Return model info: name, version, num_classes, classes, input_shape, device
# - Calculate total_parameters

if app is not None:
    # TODO: Add model info endpoint
    pass

print("TODO: /info endpoint needs implementation")

# %% [markdown]
# ## Section 2: API Testing Suite
#
# ### Task: Write comprehensive test cases for the API

# %%
# Create test client
if app is not None:
    client = TestClient(app)
    print("✅ Test client created")
else:
    print("⚠️  Cannot create test client - app not initialized")
    client = None

# %%
# Helper function to create synthetic images
# TODO: Complete this function
# Hints:
# - Create an Image.new() with specified color and size
# - Save to BytesIO
# - Seek to beginning and return

def create_test_image(size=(100, 100), color='red'):
    """Create a synthetic image for testing"""
    # TODO: Implement image creation
    pass

print("TODO: Test image helper needs implementation")

# %%
# Test Suite
test_results = {}

if client is not None:
    print("\n" + "="*70)
    print("RUNNING API TEST SUITE")
    print("="*70)
    
    # TEST 1: Health Check
    # TODO: Send GET request to /health
    # TODO: Verify status code is 200
    # TODO: Store result in test_results['health_check']
    
    if False:  # TODO: Change to True after implementing
        print("\n✅ TEST 1: Health Check Endpoint")
    
    # TEST 2: Model Info
    # TODO: Send GET request to /info
    # TODO: Verify response includes all required fields
    
    if False:  # TODO: Change to True after implementing
        print("✅ TEST 2: Model Info Endpoint")
    
    # TEST 3: Valid Image Prediction
    # TODO: Create a test image and upload to /predict
    # TODO: Verify response contains prediction and confidence
    # TODO: Check latency is > 0
    
    if False:  # TODO: Change to True after implementing
        print("✅ TEST 3: Valid Image Prediction")
    
    # TEST 4: Invalid File Type
    # TODO: Try to upload a non-image file (e.g., .txt)
    # TODO: Verify it returns 400 error
    
    if False:  # TODO: Change to True after implementing
        print("✅ TEST 4: Invalid File Type Rejection")
    
    # TEST 5: Corrupt Image
    # TODO: Send corrupted image data
    # TODO: Verify proper error handling
    
    if False:  # TODO: Change to True after implementing
        print("✅ TEST 5: Corrupt Image Handling")
    
    # TEST 6: Image Too Small
    # TODO: Create a very small image (e.g., 16x16)
    # TODO: Verify it's rejected with proper error
    
    if False:  # TODO: Change to True after implementing
        print("✅ TEST 6: Image Size Validation")
    
    # TEST 7: Multiple Consecutive Requests
    # TODO: Send 10 valid image requests
    # TODO: Verify all return 200 status
    # TODO: Verify logs are populated
    
    if False:  # TODO: Change to True after implementing
        print("✅ TEST 7: Batch Request Handling")
    
    # TEST 8: Response Time Consistency
    # TODO: Measure latency of 5 requests
    # TODO: Verify latency is consistent (std dev < 50ms)
    
    if False:  # TODO: Change to True after implementing
        print("✅ TEST 8: Latency Consistency")
else:
    print("⚠️  Skipping tests - client not initialized")

# %% [markdown]
# ## Section 3: Drift Detection System
#
# ### Task: Implement drift detection for model monitoring

# %%
# TODO: Create shifted dataset classes
# Hints:
# - BrightnessShiftedDataset: Apply ImageEnhance.Brightness
# - ContrastShiftedDataset: Apply ImageEnhance.Contrast
# - Both should inherit from torch.utils.data.Dataset
# - Both should apply transformations to images

class BrightnessShiftedDataset(torch.utils.data.Dataset):
    """TODO: Create brightness-shifted dataset"""
    def __init__(self, image_paths, brightness_factor=0.4):
        self.image_paths = image_paths
        self.brightness_factor = brightness_factor
        # TODO: Store transform pipeline
    
    def __len__(self):
        # TODO: Return number of images
        pass
    
    def __getitem__(self, idx):
        # TODO: Load image, apply brightness shift, transform, return
        pass

class ContrastShiftedDataset(torch.utils.data.Dataset):
    """TODO: Create contrast-shifted dataset"""
    def __init__(self, image_paths, contrast_factor=0.5):
        self.image_paths = image_paths
        self.contrast_factor = contrast_factor
        # TODO: Store transform pipeline
    
    def __len__(self):
        # TODO: Return number of images
        pass
    
    def __getitem__(self, idx):
        # TODO: Load image, apply contrast shift, transform, return
        pass

print("TODO: Shifted dataset classes need implementation")

# %%
# TODO: Implement DriftDetector class
# Hints:
# - Constructor takes baseline_accuracy, accuracy_threshold, jsd_threshold
# - check_accuracy_drift() method compares current vs baseline
# - check_distribution_drift() method checks KL divergence
# - generate_report() returns alert summary and recommendation
# - Recommendation should be 'RETRAIN' if alerts triggered, else 'MONITOR'

class DriftDetector:
    """TODO: Implement drift detection system"""
    def __init__(self, baseline_accuracy, accuracy_threshold=5.0, jsd_threshold=0.1):
        # TODO: Store thresholds and baseline
        pass
    
    def check_accuracy_drift(self, current_accuracy, dataset_name):
        """TODO: Check if accuracy degraded significantly"""
        pass
    
    def check_distribution_drift(self, jsd_score, dataset_name):
        """TODO: Check if input distribution shifted"""
        pass
    
    def generate_report(self):
        """TODO: Generate summary report with recommendations"""
        pass

print("TODO: DriftDetector class needs implementation")

# %%
# TODO: Evaluate model on different datasets
# Hints:
# - Create synthetic or load real shifted datasets
# - Evaluate on original images
# - Evaluate on brightness-shifted images
# - Evaluate on contrast-shifted images
# - Calculate accuracy for each

accuracies = {}
# TODO: Implement evaluation loop
# Store results in accuracies dict with keys like 'original', 'brightness', 'contrast'

if accuracies:
    print(f"✅ Evaluated {len(accuracies)} dataset versions")
else:
    print("⚠️  Evaluation not yet implemented")

# %%
# TODO: Run drift detection
# Hints:
# - Create DriftDetector with baseline from original accuracy
# - Check accuracy drift for brightness-shifted
# - Check accuracy drift for contrast-shifted
# - Generate and display report

if accuracies:
    # TODO: Initialize detector
    # TODO: Run checks
    # TODO: Display report
    print("TODO: Run drift detection")
else:
    print("⚠️  Need accuracies from previous step")

# %% [markdown]
# ## Section 4: Model Comparison & Report
#
# ### Task: Analyze results and generate insights

# %%
# TODO: Create summary statistics dataframe
# Hints:
# - Include Dataset, Accuracy, Latency, Drift Status columns
# - Rows for: Original, Brightness-Shifted, Contrast-Shifted
# - Use pd.DataFrame()

summary_df = None  # TODO: Create summary dataframe

if summary_df is not None:
    print("\n📋 SYSTEM PERFORMANCE SUMMARY")
    print("="*70)
    print(summary_df.to_string(index=False))
else:
    print("⚠️  Summary report not yet generated")

# %%
# TODO: Create visualizations
# Hints:
# - Plot 1: Accuracy comparison across datasets
# - Plot 2: Latency distribution for predictions
# - Plot 3: Test results bar chart (pass/fail)
# - Include labels, titles, and legends
# - Save figure as 'lab2_analysis.png'

if False:  # TODO: Change to True after implementing
    print("✅ Visualizations created and saved")
else:
    print("⚠️  Visualization implementation pending")

# %% [markdown]
# ## Analysis Questions
#
# Please answer the following questions based on your implementation and results:
#
# ### Question 1: API Design
# Why is input validation important in ML APIs? What specific validation did you implement and why?
#
# **Your Answer:**
# ```
# TODO: Write your answer here
# ```
#
# ### Question 2: Testing Strategy
# What are edge cases you tested for, and why is testing them critical for production systems?
#
# **Your Answer:**
# ```
# TODO: Write your answer here
# ```
#
# ### Question 3: Data Drift Impact
# What was the accuracy degradation under different drift scenarios? How does this relate to real-world deployment challenges?
#
# **Your Answer:**
# ```
# TODO: Write your answer here
# ```
#
# ### Question 4: Monitoring Strategy
# What metrics would you monitor in production? How would you set alert thresholds?
#
# **Your Answer:**
# ```
# TODO: Write your answer here
# ```
#
# ### Question 5: System Improvements
# What improvements would you recommend to make this system more robust for production deployment?
#
# **Your Answer:**
# ```
# TODO: Write your answer here
# ```

# %% [markdown]
# ## Final Summary

# %%
print("""
╔════════════════════════════════════════════════════════════════════════════════╗
║                      LAB 2 COMPLETION CHECKLIST                                 ║
╚════════════════════════════════════════════════════════════════════════════════╝

REQUIREMENTS COMPLETED:

❑ SECTION 1: API IMPLEMENTATION
  ☐ CNN Model class created and working
  ☐ Image transformation pipeline defined
  ☐ FastAPI app initialized
  ☐ /predict endpoint implemented
  ☐ /health endpoint implemented
  ☐ /info endpoint implemented

❑ SECTION 2: API TESTING
  ☐ Test 1: Health check passing
  ☐ Test 2: Model info passing
  ☐ Test 3: Valid prediction working
  ☐ Test 4: Invalid file rejection
  ☐ Test 5: Corrupt image handling
  ☐ Test 6: Size validation
  ☐ Test 7: Batch requests working
  ☐ Test 8: Latency consistent

❑ SECTION 3: DRIFT DETECTION
  ☐ Brightness-shifted dataset created
  ☐ Contrast-shifted dataset created
  ☐ DriftDetector class implemented
  ☐ Accuracy drift detection working
  ☐ Distribution drift detection working
  ☐ Alerts generated for degradation

❑ SECTION 4: ANALYSIS & REPORT
  ☐ Summary statistics calculated
  ☐ Visualizations created
  ☐ All 5 analysis questions answered
  ☐ Report saved with figures

TOTAL POINTS: ___ / 40

""")
